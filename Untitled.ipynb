# %%
from src.utils import gsdownload
# Out:
# 2024-01-01 17:51:11.615176: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-01 17:51:11.615233: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-01 17:51:11.616785: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-01 17:51:11.626881: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gsdownload("model.h5", "gs://protocell/pipeline/429426973958/oracle-20240101165659/train-model_-7314779417660620800/oracle/model.h5")

# %%
from src import aitoolkit
model = aitoolkit.load("model.h5")
characters = aitoolkit.characters
# Out:
# 2024-01-01 20:53:28.279776: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-01 20:53:28.279834: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-01 20:53:28.281369: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-01 20:53:28.290347: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
import numpy as np
X, Y = np.load("../data/words.npz").values()
X = X[:100]
Y = Y[:100]
X, Y = aitoolkit.format_data(X, Y, characters)

# %%
batch = aitoolkit.batch_prediction(model, X, Y)
# Out:
# 4/4 [==============================] - 2s 79ms/step

# %%
X, Y = np.load("../data/words.npz").values()

# %%
Y
# Out:
# array(['from', 'of', 'The', ..., 'of', 'Magyar', 'strength'], dtype='<U21')

# %%
len(max(Y, key=len))
# Out:
# 11

# %%
batch.show()

# %%
import seaborn as sns

edit_distance_values = np.array([sample.value for sample in batch])
sns.histplot(edit_distance_values, bins=10, kde=False, alpha=0.6)
# Out:
# <Axes: ylabel='Count'>

# %%
aitoolkit.edit_distance(Y_test, model(X_test)).numpy()
# Out:
# 4.36

# %%
np.mean([sample.value for sample in batch])
# Out:
# 4.36

# %%
np
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 np.mean(map(lambda x: x**2, [1, 2]))
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
#    3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/core/_methods.py:194, in _mean(a, axis, dtype, out, keepdims, where)
#     192         ret = ret.dtype.type(ret / rcount)
#     193 else:
# --> 194     ret = ret / rcount
#     196 return ret
#
# TypeError: unsupported operand type(s) for /: 'map' and 'int'
